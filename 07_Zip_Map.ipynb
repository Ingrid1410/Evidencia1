# %%
lista_numeros = [1,2,3,4,5,6,7,8]
lista_letras = ("a","e","i","o","u", "z", "x", "y")
print(lista_numeros)
print(lista_letras)

resultado_combinado = zip(lista_numeros, lista_letras)
print(f"\nEl tipo del objeto combinado resultante es {type(resultado_combinado)}")

resultado_en_lista = list(resultado_combinado)
print(f"El resultado combinado es: {resultado_en_lista}")
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# ('a', 'e', 'i', 'o', 'u', 'z', 'x', 'y')
#
# El tipo del objeto combinado resultante es <class 'zip'>
# El resultado combinado es: [(1, 'a'), (2, 'e'), (3, 'i'), (4, 'o'), (5, 'u'), (6, 'z'), (7, 'x'), (8, 'y')]

# %%
lista_numeros = [1,2,3,4,5,6]
def al_doble(valor1):
    return valor1 + valor1

numeros_al_doble = map(al_doble, lista_numeros)

#for resultado in numeros_al_doble:
#  print(resultado)

resultado_en_lista = list(numeros_al_doble)
print(f"El doble de cada elemento de la lista original : {resultado_en_lista}")


#Versión comprensión de listas
#resultado_por_comprension = [al_doble(valor) for valor in lista_numeros]
#print(resultado_por_comprension)
# Out:
# El doble de cada elemento de la lista original : [2, 4, 6, 8, 10, 12]
