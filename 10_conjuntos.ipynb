# %%
cjto = set ([1,2,3])
cjto
# Out:
# {1, 2, 3}

# %%
cjto = set ([1, 1, 2, 2, 3])
print(cjto)
# Out:
# {1, 2, 3}

# %%
#Creacion de un conjunto con valores iniciales
mi_conjunto = {"A", "B", "C", "D"}

#Creacion de un conjunto vacio
conjunto_vacio = set()

#Creacion de un conjunto a partir de un interable ya existente
lista_base = [10, 20, 30, 40, 20]
conjunto_numeros = set(lista_base)
print(conjunto_numeros)
# Out:
# {40, 10, 20, 30}

# %%
conjunto_uno = {"Hugo", "Paco", "Luis"}
conjunto_dos= {"Britni", "Llojan", "Luis"}
print("CONJUNTOS")
print(conjunto_uno)
print(conjunto_dos)
print()

#Todos los elementos de ambos conjuntos (UNIÓN)
print("UNIÓN")
print(conjunto_uno | conjunto_dos)
print()

#Aquellos elementos que existen TANTO EN UNO COMO EN OTRO conjunto (INTERSECCIÓN)
print("INTERSECCIÓN")
print(conjunto_uno & conjunto_dos)
print()

#Aquellos elementos en conjunto_uno que NO existen en conjunto_dos (DIFERENCIA)
print("DIFERENCIA")
print(conjunto_uno - conjunto_dos)
print()

#Aquellos elementos que estan en solamente uno de los dos conjuntos, pero no en ambos (DIFERENCIA SIMÉTRICA)
print("DIFERENCIA SIMËTRICA")
print(conjunto_uno ^ conjunto_dos)
# Out:
# CONJUNTOS
# {'Paco', 'Hugo', 'Luis'}
# {'Britni', 'Luis', 'Llojan'}
#
# UNIÓN
# {'Llojan', 'Paco', 'Britni', 'Hugo', 'Luis'}
#
# INTERSECCIÓN
# {'Luis'}
#
# DIFERENCIA
# {'Paco', 'Hugo'}
#
# DIFERENCIA SIMËTRICA
# {'Paco', 'Britni', 'Llojan', 'Hugo'}

# %%
conjunto_tres = {"Paco", "Luis"}

#Consulta si el conjunto_tres es un subconjunto del conjunto_uno
print(conjunto_tres <= conjunto_uno)
# Out:
# True

# %%
import random
valores = [random.randrange(1, 6) for valor in range(100)]
print(valores)

#Al obtener un conjunto a partir de la lista de valores aleatorios podremos identificar los valores únicos en ella
diferentes = set(valores)
print()
print(diferentes)
# Out:
# [5, 3, 4, 4, 3, 1, 1, 4, 1, 4, 3, 3, 3, 3, 1, 5, 5, 3, 1, 5, 4, 2, 5, 1, 3, 3, 4, 1, 2, 2, 2, 5, 4, 1, 4, 3, 1, 3, 4, 1, 3, 4, 1, 5, 1, 1, 1, 5, 1, 1, 1, 2, 2, 4, 1, 5, 1, 5, 4, 4, 5, 3, 1, 2, 2, 2, 5, 1, 2, 5, 4, 2, 4, 5, 2, 3, 2, 4, 4, 4, 5, 3, 1, 1, 3, 5, 3, 1, 3, 1, 2, 2, 4, 1, 2, 2, 5, 2, 3, 1]
#
# {1, 2, 3, 4, 5}

# %%
conjunto = set()

#Agregamos un unico elemento
conjunto.add(10)
print(conjunto)

#Agregamos multiples elementos
conjunto.update([20, 30, 40])
print(conjunto)
# Out:
# {10}
# {40, 10, 20, 30}

# %%
conjunto = {10, 20, 30, 40}
print(conjunto)

#Retiramos un valor que SI existe en el conjunto
conjunto.remove(20)
print(conjunto)

#Intentaremos retirar un valor que NO existe en el conjunto
conjunto.discard(100)
print(conjunto)

#Intentaremos retirar un valor que NO existe en el conjunto
#conjunto.remove(100) #Esto generará un error, ya que el valor 100 no existe en el conjunto
# Out:
# {40, 10, 20, 30}
# {40, 10, 30}
# {40, 10, 30}
