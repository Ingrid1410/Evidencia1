# %%
import math

valorFlotante = float(input("Introducce un valor con fraccion decimal:\n"))

print(f"El siguiente entero hacia abajo de {valorFlotante} es {math.floor(valorFlotante)}")

print(f"El siguiente entero hacia arriba de {valorFlotante} es {math.ceil(valorFlotante)}")

print(f"La parte entera truncada de {valorFlotante} es {math.trunc(valorFlotante)}")
# Out:
# Introducce un valor con fraccion decimal:
# 14.5
# El siguiente entero hacia abajo de 14.5 es 14
# El siguiente entero hacia arriba de 14.5 es 15
# La parte entera truncada de 14.5 es 14

# %%
valorNumerico = int(input("\nDame un valor entero:\n"))

print(f"La raiz cuadrada de {valorNumerico} es igual a {math.sqrt(valorNumerico)}")

print(f"El factorial de {valorNumerico} es igual a {math.factorial(valorNumerico)}")
# Out:
# Dame un valor entero:
# 4
# La raiz cuadrada de 4 es igual a 2.0
# El factorial de 4 es igual a 24

# %%
potencia = int(input("\nDame un valor entero:\n"))

print(f"El resultado de elevar {valorNumerico} a la {potencia} a potencia a {math.pow(valorNumerico)}")

print(f"El factorial de {valorNumerico} es igual a {math.factorial(valorNumerico)}")
# Out:
# Dame un valor entero:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_538/575723243.py in <cell line: 0>()
#       1 potencia = int(input("\nDame un valor entero:\n"))
#       2
# ----> 3 print(f"El resultado de elevar {valorNumerico} a la {potencia} a potencia a {math.pow(valorNumerico)}")
#       4
#       5 print(f"El factorial de {valorNumerico} es igual a {math.factorial(valorNumerico)}")
#
# TypeError: pow expected 2 arguments, got 1
