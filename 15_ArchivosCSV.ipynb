# %%
import csv
datos_a_grabar = dict()

mi_auto1 = ("BMW", 2005)
mi_auto2 = ("Toyota", 2015)

datos_a_grabar[10] = mi_auto1
datos_a_grabar[20] = mi_auto2

print(datos_a_grabar)
# Out:
# {10: ('BMW', 2005), 20: ('Toyota', 2015)}

# %%
archivo = open("autos.csv", "w", encording='latin1', newline="")

# %%
grabador = csv.writer(archivo)

# %%
grabador.writerow(("Clave", "marca", "año"))

# %%
for clave, datos in datos_a_grabar.items():
  grabador.writerow((clave, datos[0], datos[1]))

# %%
archivo.close()

# %%
import csv

datos_a_leer = dict()

with open("autos.csv", "r", enconding='latin1', newline="") as archivo:
  lector = csv.reader(archivo)
  next(lector)

  for clave, marca, año in lector:
    datos_a_leer[int(clave)] = (marca)

# %%
import csv
import sys
datos_a_leer = dict()

try:
  with open("autos.csv", "r", encoding='latin1', newline="") as archivo:
    lector = csv.reader(archivo)
    next(lector)

    for clave, marca, año in lector:
      datos_a_leer[int(clave)] = (marca, int(año))
except Exception:
  excepcion = svs.exc_info()
  print(f"Ocurrió un problema del tipo: {Excepcion[0]}")
  print(f"Mensaje del error: {Excepcion[1]}")
else:
  print(datos_a_leer)
